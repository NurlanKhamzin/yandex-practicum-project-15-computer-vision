# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px; ">
# <b> Комментарий ревьюера</b>
#
# Привет! Меня зовут Света, я буду проверять твой проект. Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
# Сразу хочу обратить внимание на цветовую разметку:
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым с пометкой ✔️ отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым с пометкой ⚠️ отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным с пометкой ❌ обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме трех перечисленных.**
# Также я попрошу тебя **не менять и не передвигать мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# <font color= 'dodgerblue'>**По проекту:**</font> работа сделана очень хорошо, все оформлено аккуратно и понятно. Структура работы у тебя грамотная, код легко читается. У меня остались некоторые вопросы, я все обозначила в комментариях. Там же я оставила рекомендации по улучшению проекта. Буду ждать работу на повторное ревью.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Спасибо за корректировки. Я оставила новые комментарии с цифрой 2. В работе все еще нет вводной части, а я не смогу принять проект без нее. Добавишь небольшое введение?
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 3</b>
#
# Теперь все супер! Надеюсь, тема была интересной. Проект я могу принять, поскольку вопросов больше нет. Желаю успехов на следующих спринтах! 😊
#
#
#
# </div>

# %% [markdown]
# # Определение возраста покупателей

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# Вводный параграф это неотъемлемая часть любого проекта, отчета, презентации или статьи. Будет очень здорово, если ты добавишь постановку задачи: краткое ее описание и описание данных. Это поможет не только тебе лучше ориентироваться в проекте спустя некоторое время, но и потенциальному работодателю, который будет просматривать твое портфолио.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2 ❌</b>
#
# Все еще нет введения :) </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 3 ✔️</h2>
#
# Это полезная привычка. Потом тебе будет проще вспоминать, что это за проект. К примеру, у меня на компьютере около сотни (если не больше) различных тетрадок с задачами, если не больше. От древних тетрадей с простыми задачами до важных проектов. Тут без комментариев ни за что не вспомнишь, о чем там речь шла и что вообще происходит в проекте :)
#
# </div>

# %% [markdown]
# Сетевой супермаркет «Хлеб-Соль» внедряет систему компьютерного зрения для обработки фотографий покупателей. Фотофиксация в прикассовой зоне поможет определять возраст клиентов, чтобы:
# - Анализировать покупки и предлагать товары, которые могут заинтересовать покупателей этой возрастной группы;
# - Контролировать добросовестность кассиров при продаже алкоголя.
# Нужно построить модель, которая по фотографии определит приблизительный возраст человека. В нашем распоряжении набор фотографий людей с указанием возраста.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50

# %%
labels = pd.read_csv('/datasets/faces/labels.csv')
datagen = ImageDataGenerator(rescale=1./255)
datagen_flow = datagen.flow_from_dataframe(
        dataframe=labels,
        directory='/datasets/faces/final_files/',
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        seed=12345)
# Out:
# Found 7591 validated image filenames.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Да, импорты лучше выносить в отдельную ячейку.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Не так критично, но я бы рекомендовала использовать более нейтральные имена. Проекты с нейросетями обычно довольно объемные, поэтому перепутать названия этого датафрейма и тренировочной подвыборки может быть легко. Да, ты определяешь выборки внутри класса или функции, но иногда мы сначала пишем каркас кода, а уже потом оборачиваем его в класс. По этой причине лучше себя обезопасить и сразу назвать датафрейм как-то иначе.
#
# </div>

# %%
labels.shape
# Out:
# (7591, 2)

# %%
labels.head(5)
# Out:
#     file_name  real_age
# 0  000000.jpg         4
# 1  000001.jpg        18
# 2  000002.jpg        80
# 3  000003.jpg        50
# 4  000004.jpg        17

# %%
ax = labels['real_age'].hist(bins=100, figsize=(10,5))
ax.set(xlabel='Возраст',ylabel='Частота',title='Распределение возраста покупателей магазина Хлеб-Соль')
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# Хорошо, что не забываешь про подписи. Однако оформлять их следует на языке заказчика. Подправь, пожалуйста.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Используй `plt.show()` или точку с запятой в конце кода, чтобы убрать подпись над графиком.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Отлично!
# </div>

# %%
pics, ages = next(datagen_flow)
fig = plt.figure(figsize=(10,10))
for i in range(16):
    fig.add_subplot(4, 4, i+1)
    plt.imshow(pics[i])
    # для компактности удаляем оси и прижимаем изображения друг к другу
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()
    plt.title(f'Возраст: {ages[i]} лет')

# %% [markdown]
# Выводы: У нас имеются 7591 изображение людей для последующей тренировки модели по определению возраста для сети супермаркетов "Хлеб-Соль". Также имеется файл с выборкой название файла и возраст людей в этих файлах. Из ходя из гистограммы возрастов наиболее всего представлена категория от 20 до 30, и наименее 60+. Соответственно модель может плохо распознавать людей данной категории. Средний возраст людей на фотографиях - 31 год, минимальный - 1 годик, максимальный - 100 лет, поэтому в гистограмме 100 корзин. Также наблюдая за фотографиями можно заметить, что ракурс не всегда прямой, то есть не всегда люди смотрят на камеру, на некоторые фотографии вообще сняты с профиля, что по моему мнению больше полезно для построения модели, чем вредит ей. Не все фотографии имеют прямой ракурс, то есть они частично повернуты.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Отличный вывод 👍
#
# </div>

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Перенесите сюда код обучения модели и её результат вывода на экран.
#
#
# (Код в этом разделе запускается в отдельном GPU-тренажёре, поэтому оформлен не как ячейка с кодом, а как код в текстовой ячейке)

# %% [markdown]
# ```python
#
# # < скопируйте код сюда >
#
# optimizer = Adam(lr=0.0001)
#
# datagen = ImageDataGenerator(validation_split=.20, rescale=1./255)
#
# def load_train(path):
#     train_datagen_flow = datagen.flow_from_dataframe(
#         dataframe=pd.read_csv(f'{path}/labels.csv'),
#         directory=f'{path}/final_files',
#         x_col='file_name',
#         y_col='real_age',
#         target_size=(224, 224),
#         batch_size=32,
#         class_mode='raw',
#         subset='training',
#         seed=12345)
#
#     return train_datagen_flow
#
# def load_test(path):
#     val_datagen_flow = datagen.flow_from_dataframe(
#         dataframe=pd.read_csv(f'{path}/labels.csv'),
#         directory=f'{path}/final_files',
#         x_col='file_name',
#         y_col='real_age',
#         target_size=(224, 224),
#         batch_size=32,
#         class_mode='raw',
#         subset='validation',
#         seed=12345)
#
#     return val_datagen_flow
#
#
#
# def create_model(input_shape=(224,224,3)):
#     backbone = ResNet50(input_shape=input_shape,
#                         weights='/datasets/keras_models/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
#                         include_top=False)
#     backbone.trainable = True
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(256, activation='relu'))
#     model.add(Dropout(0.5))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dropout(0.25))
#     model.add(Dense(64, activation='relu'))
#     model.add(Dense(32, activation='relu'))
#     model.add(Dense(1, activation='relu'))
#     model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mae'])
#
#     return model
#
#
# def train_model(model, train_data, test_data, batch_size=None, epochs=5,
#                 steps_per_epoch=None, validation_steps=None):
#
#     if steps_per_epoch is None:
#         steps_per_epoch = len(train_data)
#     if validation_steps is None:
#         validation_steps = len(test_data)
#
#
#     model.fit(train_data,
#               validation_data=test_data,
#               batch_size=batch_size, epochs=epochs,
#               steps_per_epoch=steps_per_epoch,
#               validation_steps=validation_steps,
#               verbose=2)
#
#     return model
# ```

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# - Не ясно, для чего используется линейная функция активации. Нелинейная функция работает лучше. Кроме того, у линейной область значений это все множество вещественных чисел, а у нас возрастной интервал весьма ограничен. Также не ясно, почему выбрана сигмоида. Ее лучше брать для классификации. Формально, ты можешь использовать и линейную функцию на выходе если модель должна уметь выдавать вообще любое число, а не только из какого-то конкретного интервала. Но это уже не наша задача :) Проблема тут еще и в том, что у тебя много разных функций. Сигмоида тут точно не поможет нам повысить качество обучения. Хорошо, что ты добавляешь слои. Попробуй применить везде relu (она не просто так является популярным выбором) и сравнить результаты. Если хочется улучшить модель еще, попробуй использовать dropout, например.
#
#
#
# - Обращаю внимание еще и на выбор функции потерь. Насколько корректно минимизировать какую-то функции и по значениям этой же функции проверять, насколько хорошо мы справились с задачей оптимизации? </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf;border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Комментарий студента: Исправлено по комментариям ревьюера.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Супер!
# </div>

# %% [markdown]
# ```
#
# # < скопируйте результат вывода на экран сюда >
# # < длинные строки со скачиванием модели можно удалить >
# Train for 190 steps, validate for 48 steps
# Epoch 1/5
# 2023-04-22 14:23:55.637382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-04-22 14:23:56.813822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 190/190 - 92s - loss: 268.0962 - mae: 12.0572 - val_loss: 563.1810 - val_mae: 18.5607
# Epoch 2/5
# 190/190 - 59s - loss: 104.2870 - mae: 7.6873 - val_loss: 409.4660 - val_mae: 15.1070
# Epoch 3/5
# 190/190 - 38s - loss: 73.6147 - mae: 6.4464 - val_loss: 250.1509 - val_mae: 11.6866
# Epoch 4/5
# 190/190 - 40s - loss: 58.5136 - mae: 5.7172 - val_loss: 158.2468 - val_mae: 9.3553
# Epoch 5/5
# 190/190 - 47s - loss: 48.9534 - mae: 5.2140 - val_loss: 109.1044 - val_mae: 7.8050
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 48/48 - 8s - loss: 109.1044 - mae: 7.8050
# Test MAE: 7.8050
# ```

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
#
# Результаты еще поменяются, а нужно значение метрики удастся получать значительно раньше.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf;border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Комментарий студента: Нужное значение метрики достигнуто за 5 эпох, но переобучение (разница в потерях в тренировочной и в тестовой выборках) на лицо. Его получилось избежать добавив Dropout после каждого полно связного слоя или увеличив его величину, но в этом случае метрика была далека от нужной (MAE~10-12).
#  </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# При этом, результат улучшился по сравнению с прошлым разом.
#
#
# Тут надо понимать, что задача весьма непростая, а выборка не очень большая. Я предполагаю, что мы можем добиться увеличения качества, добавив, например, какую-нибудь агументацию на тренировочную выборку. Горизонтальное отражение это весьма хорошая штука, чтобы увеличить число данных. Помимо этого, у меня есть сомнения насчет числа дополнительных слоев. Все-таки мы не с нулям пишем архитектуру, а дообучиваем существующую модель, поэтому нет необходимости в усложнении модели. Возможно, удаление слоя с 256 нейронами вместе с добавлением агументации отражения позволит улучшить метрику.
# </div>

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
# Данные были загружены через ImageDataGenerator, тренировочная и тестовая выборки разделены пропорцией 80% на 20%, значение яркости поделено на 255, размер батча - 32 изображения. Модель была обучена с помощью архитектуры ResNet50. В данной архитектуре использовался backbone без верхушки с заморозкой весов. Были использованы загруженные с сервера пред обученные веса для ResNet50. Были использованы следующие слои - упомянутый backbone, усредненный pooling, 5 полно связных слоев (кол-во нейронов уменьшалось в 2 раза с каждым слоем кроме выходного в котором был один слой, так как мы решаем задачу регрессии) с функцией активации - relu. В качестве оптимизатора использован Adam с низкой скоростью обучения - 0.0001. Эпох понадобилось 5. Начиная с 1-й эпохи заметно значительное переобучение, так как значение потери на тренировочной и тестовая выборках начало различаться. Добавление Dropout после каждого полно связного слоя (экспериментируя со значением Dropout) избавило от переобучения, но нужная метрика не была достигнута за 20 эпох. В итоге достигнута метрика средней абсолютной ошибки в 7.8 лет, что подходит под цель задачи MAE менее 8, но со значительным переобучением (в начальной версии студента нужная метрика была достигнута за 20 эпох с очень незначительным переобучением).

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Здорово, что не забываешь про общий вывод.
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Конечно, результаты удовлетворяют условиям ТЗ. Однако если смотреть на них глазами кассира, погрешность довольно большая. Как думаешь, какими способами можно улучшить качество модели?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Хорошо.</div>

# %% [markdown]
# ## Чек-лист

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Исследовательский анализ данных выполнен
# - [ ]  Результаты исследовательского анализа данных перенесены в финальную тетрадь
# - [ ]  MAE модели не больше 8
# - [ ]  Код обучения модели скопирован в финальную тетрадь
# - [ ]  Результат вывода модели на экран перенесён в финальную тетрадь
# - [ ]  По итогам обучения модели сделаны выводы
